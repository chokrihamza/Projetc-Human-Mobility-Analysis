# %% [markdown]
# <img src="../cover.png"
#      alt="Markdown Monster icon"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# <img src="../humanmobility.png"
#      alt="Markdown Monster icon"
#      style="float: left; margin-right: 10px;" />

# %% [markdown]
# ## What is scikit-mobility?
#
# ## a library to analyze <font color="red">*mobility data*</font>, suited for working with:
#
# ### - **trajectories** composed by lat/long points (e.g., GPS data)
# ### - **fluxes** of movements between places (e.g., OD matrix)

# %%
# import the library
import skmob

# %% [markdown]
# scikit-mobility provides two user-friendly data structures that extends the *pandas* `DataFrame`:
#
# - `TrajDataFrame` - for spatio-temporal <font color="blue">**trajectories**</font>
# - `FlowDataFrame` - for <font color="blue">**fluxes**</font> mapped into a tessellation

# %% [markdown]
# ### What you can do with scikit-mobility?
#
# ✅;Preprocessing of mobility data </br>
# ✅Measuring individual and collective behaviours </br>
# ✅Assessing privacy risk </br>
# ✅Predicting migration flows </br>
# ✅<font color="grey">**Generating** synthetic trajectories</font>

# %% [markdown]
# ## `TrajDataFrame`
#
#
# Each row describes a trajectory's point and contains the following columns:
#
# - `lat` - latitude of the point
# - `lng` - longitude of the point
# - `datetime` - date and time of the point

# %% [markdown]
# For multi-user data sets, there are two *optional* columns:
#
# - `uid` - user's identifier to which the trajectory belongs to
# - `tid` - identifier for the trajectory

# %% [markdown]
# A `TrajDataFrame` can be created from:
#
# - a python list or *numpy* array
# - a python dictionary
# - a *pandas* `DataFrame`
# - a text file

# %% [markdown]
# ### From a `list`

# %%
# From a list
data_list = [[1, 39.984094, 116.319236, '2008-10-23 13:53:05'],
             [1, 39.984198, 116.319322, '2008-10-23 13:53:06'],
             [1, 39.984224, 116.319402, '2008-10-23 13:53:11'],
             [1, 39.984211, 116.319389, '2008-10-23 13:53:16']]
data_list
# Out:
# [[1, 39.984094, 116.319236, '2008-10-23 13:53:05'],
#  [1, 39.984198, 116.319322, '2008-10-23 13:53:06'],
#  [1, 39.984224, 116.319402, '2008-10-23 13:53:11'],
#  [1, 39.984211, 116.319389, '2008-10-23 13:53:16']]

# %% [markdown]
# We must set the indexes of the mandatory columns using arguments `latitude`, `longitude` and `datetime`.

# %%
tdf = skmob.TrajDataFrame(data_list, 
                          latitude=1, longitude=2, 
                          datetime=3)
print(type(tdf))
tdf
# Out:
# <class 'skmob.core.trajectorydataframe.TrajDataFrame'>
#    0        lat         lng            datetime
# 0  1  39.984094  116.319236 2008-10-23 13:53:05
# 1  1  39.984198  116.319322 2008-10-23 13:53:06
# 2  1  39.984224  116.319402 2008-10-23 13:53:11
# 3  1  39.984211  116.319389 2008-10-23 13:53:16

# %% [markdown]
# ### From a `DataFrame`

# %%
# import the pandas library
import pandas as pd 
# build a dataframe from the 2D list
data_df = pd.DataFrame(data_list, 
                       columns=['user', 'latitude', 'lng', 'hour'])

# %%
print(type(data_df)) # type of the structure
data_df.head() # head of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
#    user   latitude         lng                 hour
# 0     1  39.984094  116.319236  2008-10-23 13:53:05
# 1     1  39.984198  116.319322  2008-10-23 13:53:06
# 2     1  39.984224  116.319402  2008-10-23 13:53:11
# 3     1  39.984211  116.319389  2008-10-23 13:53:16

# %% [markdown]
# Note that:
# - name of columns in `data_df` don't match the names required
# - you must specify the names of the mandatory columns using arguments `latitude`, `longitude` and `datetime`

# %%
# Create a TrajDataFrame from a DataFrame
tdf = skmob.TrajDataFrame(data_df, 
                          latitude='latitude', 
                          datetime='hour', 
                          user_id='user')

print(type(tdf))
tdf.head()
# Out:
# <class 'skmob.core.trajectorydataframe.TrajDataFrame'>
#    uid        lat         lng            datetime
# 0    1  39.984094  116.319236 2008-10-23 13:53:05
# 1    1  39.984198  116.319322 2008-10-23 13:53:06
# 2    1  39.984224  116.319402 2008-10-23 13:53:11
# 3    1  39.984211  116.319389 2008-10-23 13:53:16

# %% [markdown]
# ### From a text file
#
# Class `TrajDataFrame` has a method `from_file` to construct the object from an input text file.
#
# Let's try with a subsample of the <font color="blue">**GeoLife**</font> trajectories. The whole dataset can be found [here](https://www.microsoft.com/en-us/download/details.aspx?id=52367).

# %%
# create a TrajDataFrame from a dataset of trajectories 
tdf = skmob.TrajDataFrame.from_file(
    './data/geolife_sample.txt.gz', sep=',')
print(type(tdf))
# Out:
# <class 'skmob.core.trajectorydataframe.TrajDataFrame'>

# %%
# explore the TrajDataFrame
tdf.head(10)
# Out:
#          lat         lng            datetime  uid
# 0  39.984094  116.319236 2008-10-23 05:53:05    1
# 1  39.984198  116.319322 2008-10-23 05:53:06    1
# 2  39.984224  116.319402 2008-10-23 05:53:11    1
# 3  39.984211  116.319389 2008-10-23 05:53:16    1
# 4  39.984217  116.319422 2008-10-23 05:53:21    1
# 5  39.984710  116.319865 2008-10-23 05:53:23    1
# 6  39.984674  116.319810 2008-10-23 05:53:28    1
# 7  39.984623  116.319773 2008-10-23 05:53:33    1
# 8  39.984606  116.319732 2008-10-23 05:53:38    1
# 9  39.984555  116.319728 2008-10-23 05:53:43    1

# %%
tdf.tail(10)
# Out:
#               lat         lng            datetime  uid
# 217643  40.000205  116.327173 2009-03-19 05:45:37    5
# 217644  40.000128  116.327171 2009-03-19 05:45:42    5
# 217645  40.000069  116.327179 2009-03-19 05:45:47    5
# 217646  40.000001  116.327219 2009-03-19 05:45:52    5
# 217647  39.999919  116.327211 2009-03-19 05:45:57    5
# 217648  39.999896  116.327290 2009-03-19 05:46:02    5
# 217649  39.999899  116.327352 2009-03-19 05:46:07    5
# 217650  39.999945  116.327394 2009-03-19 05:46:12    5
# 217651  40.000015  116.327433 2009-03-19 05:46:17    5
# 217652  39.999978  116.327460 2009-03-19 05:46:37    5

# %% [markdown]
# ### Attributes of a `TrajDataFrame`
#
#
# - `crs`: the coordinate reference system. Default: `epsg:4326` (lat/long)
# - `parameters`: dictionary to add as many as necessary additional properties

# %%
tdf.crs
# Out:
# {'init': 'epsg:4326'}

# %%
tdf.parameters
# Out:
# {'from_file': './data/geolife_sample.txt.gz'}

# %%
# add your own parameter
tdf.parameters['IGS Tunis'] = 'Groupe IGC 2022'
tdf.parameters
# Out:
# {'from_file': './data/geolife_sample.txt.gz', 'IGS Tunis': 'Groupe IGC 2022'}

# %% [markdown]
# Columns of `TrajDataFrame` have specific types

# %%
# In the DataFrame
print(type(data_df))
data_df.dtypes
# Out:
# <class 'pandas.core.frame.DataFrame'>
# user          int64
# latitude    float64
# lng         float64
# hour         object
# dtype: object

# %%
print(type(tdf)) # In the TrajDataFrame
tdf.dtypes
# Out:
# <class 'skmob.core.trajectorydataframe.TrajDataFrame'>
# lat                float64
# lng                float64
# datetime    datetime64[ns]
# uid                  int64
# dtype: object

# %%
tdf.lat.head()
# Out:
# 0    39.984094
# 1    39.984198
# 2    39.984224
# 3    39.984211
# 4    39.984217
# Name: lat, dtype: float64

# %% [markdown]
# ### Write and read
#
# To write/read a `TrajDataFrame` into a file, scikit-mobility provides ad-hoc methods.

# %% [markdown]
# #### Writing a `TrajDataFrame` to a file
#
# - includes the `parameters` and `crs`attributes
# - preserves `dtype` of columns with timestamps (time zone info is lost though).

# %%
skmob.write(tdf, './tdf.json')

# %%
tdf.parameters
# Out:
# {'from_file': './data/geolife_sample.txt.gz', 'IGS Tunis': 'Groupe IGC 2022'}

# %% [markdown]
# ### Read a `TrajDataFrame` from a json file

# %%
# read the file written before
tdf2 = skmob.read('./tdf.json') 
tdf2[:6]
# Out:
#          lat         lng            datetime  uid
# 0  39.984094  116.319236 2008-10-23 05:53:05    1
# 1  39.984198  116.319322 2008-10-23 05:53:06    1
# 2  39.984224  116.319402 2008-10-23 05:53:11    1
# 3  39.984211  116.319389 2008-10-23 05:53:16    1
# 4  39.984217  116.319422 2008-10-23 05:53:21    1
# 5  39.984710  116.319865 2008-10-23 05:53:23    1

# %% [markdown]
# `dtype`s and the `parameters` and `crs` attributes are preserved

# %%
print(tdf2.dtypes)
tdf2.parameters
# Out:
# lat                float64
# lng                float64
# datetime    datetime64[ns]
# uid                  int64
# dtype: object
# {'from_file': './data/geolife_sample.txt.gz', 'IGS Tunis': 'Groupe IGC 2022'}

# %% [markdown]
# ### Plotting trajectories and flows
#
# *scikit-mobility* relies on the *folium* library to plot:
# - trajectories
# - flows
# - tessellations

# %%
tdf.plot_trajectory(zoom=12, weight=3, opacity=0.8, tiles='Stamen Toner')
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3601254942e87a87f2affb51263b4020 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3601254942e87a87f2affb51263b4020&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3601254942e87a87f2affb51263b4020 = L.map(
#                 &quot;map_3601254942e87a87f2affb51263b4020&quot;,
#                 {
#                     center: [39.9962335, 116.32167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3601254942e87a87f2affb51263b4020);
#
#
#
#
#
#             var tile_layer_124b1bb648b6d4937e61d25902c47184 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3601254942e87a87f2affb51263b4020);
#
#
#         function geo_json_2c46fbf6d62a0bbe77838b529ec44147_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#6A0213&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.8, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_2c46fbf6d62a0bbe77838b529ec44147_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_2c46fbf6d62a0bbe77838b529ec44147 = L.geoJson(null, {
#                 onEachFeature: geo_json_2c46fbf6d62a0bbe77838b529ec44147_onEachFeature,
#
#                 style: geo_json_2c46fbf6d62a0bbe77838b529ec44147_styler,
#         });
#
#         function geo_json_2c46fbf6d62a0bbe77838b529ec44147_add (data) {
#             geo_json_2c46fbf6d62a0bbe77838b529ec44147
#                 .addData(data)
#                 .addTo(map_3601254942e87a87f2affb51263b4020);
#         }
#             geo_json_2c46fbf6d62a0bbe77838b529ec44147_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[116.319236, 39.984094], [116.324395, 39.979764], [116.326728, 39.984062], [116.326543, 39.993742], [116.32167, 40.001626], [116.31591, 40.009559], [116.310135, 40.016448], [116.305591, 40.014572], [116.306529, 40.01382], [116.306526, 40.013859], [116.31256, 40.010884], [116.320113, 40.004924], [116.32627, 39.997362], [116.326817, 39.98674], [116.325772, 39.978983], [116.324616, 39.979582], [116.310814, 39.980075], [116.308814, 39.981103], [116.310729, 39.981595], [116.313583, 39.979542], [116.313722, 39.979553], [116.327028, 39.979859], [116.326168, 39.978777], [116.325387, 39.979729], [116.310938, 39.980088], [116.310485, 39.981422], [116.310913, 39.981931], [116.312635, 39.979568], [116.323849, 39.979524], [116.30576, 40.015904], [116.310613, 40.015327], [116.311899, 40.013635], [116.309028, 40.003765], [116.309026, 39.998026], [116.300121, 39.996491], [116.291189, 39.99598], [116.280083, 39.997194], [116.267794, 40.002691], [116.250253, 40.004855], [116.236305, 39.999345], [116.220385, 39.995421], [116.213343, 39.992248], [116.207124, 39.992479], [116.201177, 39.993741], [116.198934, 39.997028], [116.196825, 39.996838], [116.196669, 39.997212], [116.195698, 39.999913], [116.192199, 40.002138], [116.189877, 40.005311], [116.185017, 40.004414], [116.18101, 40.002771], [116.175774, 40.002766], [116.172672, 40.000699], [116.171119, 40.001718], [116.170751, 40.002577], [116.169433, 40.002429], [116.167575, 40.002232], [116.166736, 40.00174], [116.165926, 40.000155], [116.16209, 39.999291], [116.156125, 39.998647], [116.15132, 39.997193], [116.14741, 39.993966], [116.145321, 39.993154], [116.147363, 39.993923], [116.152825, 39.997664], [116.157881, 39.997812], [116.161717, 39.995573], [116.167572, 39.995071], [116.169461, 39.994648], [116.173318, 39.996042], [116.176718, 39.996848], [116.179708, 39.99684], [116.184516, 39.995428], [116.187584, 39.992407], [116.187005, 39.989942], [116.186206, 39.989155], [116.18821, 39.988959], [116.188529, 39.988176], [116.191276, 39.98977], [116.193994, 39.99103], [116.197219, 39.991895], [116.203145, 39.99146], [116.204994, 39.992475], [116.215251, 39.991429], [116.246945, 40.004265], [116.262046, 40.004073], [116.275639, 40.00045], [116.285521, 39.996866], [116.294892, 39.996003], [116.308795, 39.998014], [116.309348, 40.003968], [116.312223, 40.013299], [116.305672, 40.014134], [116.311501, 40.017163], [116.307487, 40.026715], [116.314128, 40.031998], [116.305672, 40.0437], [116.297114, 40.057642], [116.31043, 40.069592], [116.329794, 40.069405], [116.338666, 40.071323], [116.342078, 40.075335], [116.339464, 40.074122], [116.336552, 40.069872], [116.330634, 40.069676], [116.330137, 40.069522], [116.312949, 40.069538], [116.296869, 40.057774], [116.305267, 40.04412], [116.31408, 40.031764], [116.321623, 40.015654], [116.331197, 40.001672], [116.3315,

# %% [markdown]
# ## `FlowDataFrame`
#
# Each row describes a flow and contains the columns:
#
# - `origin`: ID of the origin tile
# - `destination`: ID of the destination tile
# - `flow`: number of people travelling from `origin` to `destination`
#
# <!-- NOTE: `FlowDataFrame` is a dataframe way of having Origin-Destination Matrix. -->

# %% [markdown]
# ### Tessellation
# Each `FlowDataFrame` is associated  with a <font color="blue">**tessellation**</font>, i.e., a `GeoDataFrame` that  contains two columns:
# - `tile_ID`, identifier of a location
# - `geometry`, geometric shape of the location

# %% [markdown]
# ### Create of a `FlowDataFrame`
#
# The `FlowDataFrame` can be created from:
#
# - a python list or a numpy array
# - a *pandas* `DataFrame`
# - a python dictionary
# - a text file

# %% [markdown]
# ### From a file
#
# method `from_file` creates a `FlowDataFrame` from a text file with the format:
#
# - `origin`, `destination`, `flow`, `datetime` (optional)

# %%
import geopandas as gpd # Let's import geopandas

# %%
tessellation = gpd.GeoDataFrame.from_file(
    "data/NY_counties_2011.geojson") # load a tessellation

# create a FlowDataFrame from a file and a tessellation
fdf = skmob.FlowDataFrame.from_file(
    "data/NY_commuting_flows_2011.csv",
    tessellation=tessellation, tile_id='tile_id', sep=",")

# %%
fdf.head()
# Out:
#      flow origin destination
# 0  121606  36001       36001
# 1       5  36001       36005
# 2      29  36001       36007
# 3      11  36001       36017
# 4      30  36001       36019

# %%
fdf.dtypes
# Out:
# flow            int64
# origin         object
# destination    object
# dtype: object

# %%
# The tessellation is an attribute of the FlowDataFrame
fdf.tessellation.head()
# Out:
#   tile_ID  population                                           geometry
# 0   36019       81716  POLYGON ((-74.00667 44.88602, -74.02739 44.995...
# 1   36101       99145  POLYGON ((-77.09975 42.27421, -77.09966 42.272...
# 2   36107       50872  POLYGON ((-76.25015 42.29668, -76.24914 42.302...
# 3   36059     1346176  POLYGON ((-73.70766 40.72783, -73.70027 40.739...
# 4   36011       79693  POLYGON ((-76.27907 42.78587, -76.27535 42.780...

# %% [markdown]
# ### Plot the tessellation

# %%
fdf.plot_tessellation(popup_features=['tile_ID', 'population'])
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\utils\plot.py:635: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   vertices = [list(zip(*p.exterior.xy)) for p in gway]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92a21cdb5e6790d7c300a53563216904 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92a21cdb5e6790d7c300a53563216904&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92a21cdb5e6790d7c300a53563216904 = L.map(
#                 &quot;map_92a21cdb5e6790d7c300a53563216904&quot;,
#                 {
#                     center: [42.555968337076926, -75.47699722292556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_92a21cdb5e6790d7c300a53563216904);
#
#
#
#
#
#             var tile_layer_47c2bb055746a70f5cc2c45c58d22e74 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_92a21cdb5e6790d7c300a53563216904);
#
#
#         function geo_json_e7055b4f92607003e8daaac2fafd7362_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#28B541&quot;, &quot;fillColor&quot;: &quot;#28B541&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_e7055b4f92607003e8daaac2fafd7362_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_e7055b4f92607003e8daaac2fafd7362 = L.geoJson(null, {
#                 onEachFeature: geo_json_e7055b4f92607003e8daaac2fafd7362_onEachFeature,
#
#                 style: geo_json_e7055b4f92607003e8daaac2fafd7362_styler,
#         });
#
#         function geo_json_e7055b4f92607003e8daaac2fafd7362_add (data) {
#             geo_json_e7055b4f92607003e8daaac2fafd7362
#                 .addData(data)
#                 .addTo(map_92a21cdb5e6790d7c300a53563216904);
#         }
#             geo_json_e7055b4f92607003e8daaac2fafd7362_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-74.006668, 44.886017], [-74.027389, 44.995685], [-73.874597, 45.001223], [-73.639718, 45.003464], [-73.343124, 45.01084], [-73.354633, 44.987352], [-73.350218, 44.976222], [-73.338244, 44.964751], [-73.339603, 44.943371], [-73.338979, 44.917681], [-73.341106, 44.914632], [-73.350652, 44.909634], [-73.356218, 44.904492], [-73.360328, 44.897236], [-73.369104, 44.866681], [-73.371968, 44.862415], [-73.379822, 44.857038], [-73.379545, 44.851651], [-73.38159, 44.849354], [-73.380321, 44.847173], [-73.381336, 44.844683], [-73.379447, 44.843461], [-73.379452, 44.83801], [-73.375346, 44.836307], [-73.368275, 44.828007], [-73.353472, 44.820386], [-73.335044, 44.804109], [-73.333154, 44.788759], [-73.335713, 44.782086], [-73.347085, 44.77298], [-73.354361, 44.755296], [-73.365562, 44.741786], [-73.365977, 44.697559], [-73.361308, 44.694524], [-73.365297, 44.687548], [-73.370142, 44.684855], [-73.367209, 44.678514], [-73.371843, 44.676957], [-73.37101, 44.672763], [-73.372719, 44.668739], [-73.369668, 44.663478], [-73.374577, 44.66189], [-73.379073, 44.656772], [-73.378317, 44.652165], [-73.384483, 44.646683], [-73.37856, 44.641476], [-73.386783, 44.63637], [-73.386497, 44.626925], [-73.390231, 44.618354], [-73.382932, 44.612184], [-73.380725, 44.60524], [-73.376849, 44.599599], [-73.376806, 44.595456], [-73.381849, 44.589316], [-73.375667, 44.582038], [-73.37495, 44.575817], [-73.356789, 44.557919], [-73.342933, 44.551907], [-73.338636, 44.546844], [-73.463838, 44.537681], [-73.464909, 44.533812], [-73.462879, 44.533182], [-73.460977, 44.529614], [-73.463588, 44.525035], [-73.45942, 44.523172], [-73.45965, 44.520046], [-73.465891, 44.518987], [-73.471045, 44.514614], [-73.470835, 44.507822], [-73.479567, 44.506724], [-73.48316, 44.501258], [-73.490367, 44.49792], [-73.491309, 44.49375], [-73.496604, 44.486081], [-73.500563, 44.488477], [-73.506721, 44.487213], [-73.516455, 44.488066], [-73.524413, 44.493241], [-73.523636, 44.490406], [-73.526907, 44.488028], [-73.540856, 44.486333], [-73.547562, 44.482692], [-73.55497, 44.482549], [-73.559429, 44.478789], [-73.561996, 44.471012], [-73.573099, 44.464564], [-73.580957, 44.464489], [-73.590698, 44.461098], [-73.596836, 44.463109], [-73.602349, 44.458128], [-73.613894, 44.454442], [-73.629049, 44.458391], [-73.638955, 44.452553], [-73.654264, 44.448518], [-73.658335, 44.443887], [-73.669281, 44.441355], [-73.674479, 44.440649], [-73.681188, 44.442231], [-73.689457, 44.44098], [-73.695519, 44.44243], [-73.700298, 44.440452], [-73.700717, 44.445571], [-73.909687, 44.429699], [-73.920241, 44.504462], [-73.932927, 44.576197], [-73.9459, 44.574869], [-73.966148, 44.709118], [-73.986382, 44.707773], [-73.993942, 44.764663], [-74.006692, 44.836938], [-74.006668, 44.886017]]], &quot;type&quot;: &quot;Polyg

# %% [markdown]
# ### Plot the flows

# %%
fdf.plot_flows(flow_color='green')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_604bf39d04b9cb7cdf066fada38b67b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_604bf39d04b9cb7cdf066fada38b67b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_604bf39d04b9cb7cdf066fada38b67b6 = L.map(
#                 &quot;map_604bf39d04b9cb7cdf066fada38b67b6&quot;,
#                 {
#                     center: [42.555968337076926, -75.47699722292556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_604bf39d04b9cb7cdf066fada38b67b6);
#
#
#
#
#
#             var tile_layer_62a1746af64512a758f9cea7eacd9c3d = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_604bf39d04b9cb7cdf066fada38b67b6);
#
#
#         function geo_json_d99b9c8d1246e9816b46c03ffb34f313_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 0.16629883492694078};
#             }
#         }
#
#         function geo_json_d99b9c8d1246e9816b46c03ffb34f313_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d99b9c8d1246e9816b46c03ffb34f313 = L.geoJson(null, {
#                 onEachFeature: geo_json_d99b9c8d1246e9816b46c03ffb34f313_onEachFeature,
#
#                 style: geo_json_d99b9c8d1246e9816b46c03ffb34f313_styler,
#         });
#
#         function geo_json_d99b9c8d1246e9816b46c03ffb34f313_add (data) {
#             geo_json_d99b9c8d1246e9816b46c03ffb34f313
#                 .addData(data)
#                 .addTo(map_604bf39d04b9cb7cdf066fada38b67b6);
#         }
#             geo_json_d99b9c8d1246e9816b46c03ffb34f313_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-73.973506, 42.600164], [-73.852926, 40.849097]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_1085b2f5ddb59f29ea763966c098151b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 0.400500629823145};
#             }
#         }
#
#         function geo_json_1085b2f5ddb59f29ea763966c098151b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1085b2f5ddb59f29ea763966c098151b = L.geoJson(null, {
#                 onEachFeature: geo_json_1085b2f5ddb59f29ea763966c098151b_onEachFeature,
#
#                 style: geo_json_1085b2f5ddb59f29ea763966c098151b_styler,
#         });
#
#         function geo_json_1085b2f5ddb59f29ea763966c098151b_add (data) {
#             geo_json_1085b2f5ddb59f29ea763966c098151b
#                 .addData(data)
#                 .addTo(map_604bf39d04b9cb7cdf066fada38b67b6);
#         }
#             geo_json_1085b2f5ddb59f29ea763966c098151b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-73.973506, 42.600164], [-75.81962, 42.160117]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_1132737f9db875dada5384970d058c56_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;green&quot;, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 0.24666103359818992};
#             }
#         }
#
#         function geo_json_1132737f9db875dada5384970d058c56_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1132737f9db875dada5384970d058c56 = L.geoJson(null, {
#                 onEachFeature: geo_json_1132737f9db875dada5384970d058c56_onEachFeature,
#
#                 style: geo_json_1132737f9db875dada5384970d058c56_styler,
#         });
#
#         function geo_json_1132737f9db875dada5384970d058c56_add (data) {
#             geo_json_1132737f9db875dada5384970d058c56
#                 .addData(data)
#                 .addTo(map_604bf39d04b9cb7cdf066fada38b67b6);
#         }
#             geo_json_1132737f9db875dada5384970d058c56_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[-73.973506, 42.600164], [-75.611582, 42.493581]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;type&quot;: &quot;Feature&quot;}], &quot;type&quot;: &quot;FeatureCollection&quot;});
#
#
#
#         function geo_json_121155d41640e

# %% [markdown]
# ### Plot tessellation and flows

# %%
map_f = fdf.plot_tessellation(style_func_args={'color':'blue', 'fillColor':'blue'})
fdf[fdf['origin'] == '36061'].plot_flows(map_f=map_f, flow_exp=0., flow_popup=True)
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\utils\plot.py:635: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   vertices = [list(zip(*p.exterior.xy)) for p in gway]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e5db6938b1310a86c3b4b7a20d1e97d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e5db6938b1310a86c3b4b7a20d1e97d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e5db6938b1310a86c3b4b7a20d1e97d = L.map(
#                 &quot;map_2e5db6938b1310a86c3b4b7a20d1e97d&quot;,
#                 {
#                     center: [42.555968337076926, -75.47699722292556],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_2e5db6938b1310a86c3b4b7a20d1e97d);
#
#
#
#
#
#             var tile_layer_e4e3f46068de218c6c14c2e714ff3fd0 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_2e5db6938b1310a86c3b4b7a20d1e97d);
#
#
#         function geo_json_08c3053b09c7bcc47384b91d3ec979c0_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.25, &quot;opacity&quot;: 0.5, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_08c3053b09c7bcc47384b91d3ec979c0_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_08c3053b09c7bcc47384b91d3ec979c0 = L.geoJson(null, {
#                 onEachFeature: geo_json_08c3053b09c7bcc47384b91d3ec979c0_onEachFeature,
#
#                 style: geo_json_08c3053b09c7bcc47384b91d3ec979c0_styler,
#         });
#
#         function geo_json_08c3053b09c7bcc47384b91d3ec979c0_add (data) {
#             geo_json_08c3053b09c7bcc47384b91d3ec979c0
#                 .addData(data)
#                 .addTo(map_2e5db6938b1310a86c3b4b7a20d1e97d);
#         }
#             geo_json_08c3053b09c7bcc47384b91d3ec979c0_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-74.006668, 44.886017], [-74.027389, 44.995685], [-73.874597, 45.001223], [-73.639718, 45.003464], [-73.343124, 45.01084], [-73.354633, 44.987352], [-73.350218, 44.976222], [-73.338244, 44.964751], [-73.339603, 44.943371], [-73.338979, 44.917681], [-73.341106, 44.914632], [-73.350652, 44.909634], [-73.356218, 44.904492], [-73.360328, 44.897236], [-73.369104, 44.866681], [-73.371968, 44.862415], [-73.379822, 44.857038], [-73.379545, 44.851651], [-73.38159, 44.849354], [-73.380321, 44.847173], [-73.381336, 44.844683], [-73.379447, 44.843461], [-73.379452, 44.83801], [-73.375346, 44.836307], [-73.368275, 44.828007], [-73.353472, 44.820386], [-73.335044, 44.804109], [-73.333154, 44.788759], [-73.335713, 44.782086], [-73.347085, 44.77298], [-73.354361, 44.755296], [-73.365562, 44.741786], [-73.365977, 44.697559], [-73.361308, 44.694524], [-73.365297, 44.687548], [-73.370142, 44.684855], [-73.367209, 44.678514], [-73.371843, 44.676957], [-73.37101, 44.672763], [-73.372719, 44.668739], [-73.369668, 44.663478], [-73.374577, 44.66189], [-73.379073, 44.656772], [-73.378317, 44.652165], [-73.384483, 44.646683], [-73.37856, 44.641476], [-73.386783, 44.63637], [-73.386497, 44.626925], [-73.390231, 44.618354], [-73.382932, 44.612184], [-73.380725, 44.60524], [-73.376849, 44.599599], [-73.376806, 44.595456], [-73.381849, 44.589316], [-73.375667, 44.582038], [-73.37495, 44.575817], [-73.356789, 44.557919], [-73.342933, 44.551907], [-73.338636, 44.546844], [-73.463838, 44.537681], [-73.464909, 44.533812], [-73.462879, 44.533182], [-73.460977, 44.529614], [-73.463588, 44.525035], [-73.45942, 44.523172], [-73.45965, 44.520046], [-73.465891, 44.518987], [-73.471045, 44.514614], [-73.470835, 44.507822], [-73.479567, 44.506724], [-73.48316, 44.501258], [-73.490367, 44.49792], [-73.491309, 44.49375], [-73.496604, 44.486081], [-73.500563, 44.488477], [-73.506721, 44.487213], [-73.516455, 44.488066], [-73.524413, 44.493241], [-73.523636, 44.490406], [-73.526907, 44.488028], [-73.540856, 44.486333], [-73.547562, 44.482692], [-73.55497, 44.482549], [-73.559429, 44.478789], [-73.561996, 44.471012], [-73.573099, 44.464564], [-73.580957, 44.464489], [-73.590698, 44.461098], [-73.596836, 44.463109], [-73.602349, 44.458128], [-73.613894, 44.454442], [-73.629049, 44.458391], [-73.638955, 44.452553], [-73.654264, 44.448518], [-73.658335, 44.443887], [-73.669281, 44.441355], [-73.674479, 44.440649], [-73.681188, 44.442231], [-73.689457, 44.44098], [-73.695519, 44.44243], [-73.700298, 44.440452], [-73.700717, 44.445571], [-73.909687, 44.429699], [-73.920241, 44.504462], [-73.932927, 44.576197], [-73.9459, 44.574869], [-73.966148, 44.709118], [-73.986382, 44.707773], [-73.993942, 44.764663], [-74.006692, 44.836938], [-74.006668, 44.886017]]], &quot;type&quot;: &quot;Polygon&quo
