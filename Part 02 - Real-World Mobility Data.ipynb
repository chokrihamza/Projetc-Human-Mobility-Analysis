# %% [markdown]
# <center><img src="logo_skmob.png" width=450 align="left" /></center>
#
# # Real-World Mobility data Example

# %% [markdown]
# ## Social Media: the <font color="red">Brightkite</font> data set
# [Brightkite](https://snap.stanford.edu/data/loc-brightkite.html) was a location-based social networking service provider where users shared their locations by checking-in in the period Apr 2008 - Oct 2010:
# - 58,228 users
# - 4,491,143 checkins
#
# <center><img src="snap.png" width=800   align="left" /></center>

# %%
# import the skmob and pandas libraries
import skmob
import pandas as pd

# load the pandas DataFrame
url = "Brightkite_totalCheckins.txt"
df = pd.read_csv(url, sep='\t', header=0, nrows=100000, names=['user', 'check-in_time', 'latitude', 'longitude', 'location id'])

# convert it to a TrajDataFrame
bdf = skmob.TrajDataFrame(df, latitude='latitude', longitude='longitude', datetime='check-in_time', user_id='user')
bdf.head(10)
# Out:
#    uid                  datetime        lat         lng  \
# 0    0 2010-10-16 06:02:04+00:00  39.891383 -105.070814
# 1    0 2010-10-16 03:48:54+00:00  39.891077 -105.068532
# 2    0 2010-10-14 18:25:51+00:00  39.750469 -104.999073
# 3    0 2010-10-14 00:21:47+00:00  39.752713 -104.996337
# 4    0 2010-10-13 23:31:51+00:00  39.752508 -104.996637
# 5    0 2010-10-13 20:05:43+00:00  39.751300 -105.000121
# 6    0 2010-10-13 16:41:35+00:00  39.758974 -105.010853
# 7    0 2010-10-13 03:57:23+00:00  39.827022 -105.143191
# 8    0 2010-10-12 19:56:49+00:00  39.749934 -105.000017
# 9    0 2010-10-11 02:51:09+00:00  39.891077 -105.068532
#
#                                 location id
# 0          7a0f88982aa015062b95e3b4843f9ca2
# 1          dd7cd3d264c2d063832db506fba8bf79
# 2  9848afcc62e500a01cf6fbf24b797732f8963683
# 3          2ef143e12038c870038df53e0478cefc
# 4          424eb3dd143292f9e013efa00486c907
# 5  d268093afe06bd7d37d91c4d436e0c40d217b20a
# 6          6f5b96170b7744af3c7577fa35ed0b8f
# 7          f6f52a75fd80e27e3770cd3a87054f27
# 8          b3d356765cc8a4aa7ac5cd18caafd393
# 9          6f3a2db56d4fa788f72def616f79b7a4

# %%
bdf['leaving_datetime'] = bdf.datetime
# take the points of a single user
user0_bdf = bdf[bdf.uid == bdf.uid.unique()[0]]
# take a sample of 200 random points
user0_bdf_sample = user0_bdf.sample(200)
# plot the stops of the user
user0_map = user0_bdf_sample.plot_stops(zoom=3)
# plot the trajectory of the user
user0_bdf_sample.plot_trajectory(map_f=user0_map)
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:646: UserWarning: Only the stops of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_stops(self, map_f=map_f, max_users=max_users, tiles=tiles, zoom=zoom,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43892c98d8e6a1b6bc20f9b4079aea9a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43892c98d8e6a1b6bc20f9b4079aea9a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43892c98d8e6a1b6bc20f9b4079aea9a = L.map(
#                 &quot;map_43892c98d8e6a1b6bc20f9b4079aea9a&quot;,
#                 {
#                     center: [39.7580645, -104.99482],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_43892c98d8e6a1b6bc20f9b4079aea9a);
#
#
#
#
#
#             var tile_layer_5a93c3c94dd581d49236599921b0f667 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_43892c98d8e6a1b6bc20f9b4079aea9a);
#
#
#             var regular_polygon_marker_329c49e0251d179476d9fcf43d7ba81c = new L.RegularPolygonMarker(
#                 [39.743258, -104.969737],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008169&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008169&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_43892c98d8e6a1b6bc20f9b4079aea9a);
#
#
#         var popup_6d4d6c227972402011974c72e97071aa = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_767eab1fe010ef9da96118964b435dcd = $(`&lt;div id=&quot;html_767eab1fe010ef9da96118964b435dcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User: 0&lt;BR&gt;Coord: &lt;a href=&quot;https://www.google.co.uk/maps/place/39.743258,-104.969737&quot; target=&quot;_blank&quot;&gt;39.7433, -104.9697&lt;/a&gt;&lt;BR&gt;Arr: 2009/11/10 03:52&lt;BR&gt;Dep: 2009/11/10 03:52&lt;/div&gt;`)[0];
#                 popup_6d4d6c227972402011974c72e97071aa.setContent(html_767eab1fe010ef9da96118964b435dcd);
#
#
#
#         regular_polygon_marker_329c49e0251d179476d9fcf43d7ba81c.bindPopup(popup_6d4d6c227972402011974c72e97071aa)
#         ;
#
#
#
#
#             var regular_polygon_marker_14c1ccd0d1ac9e9e994cc31f9544b63a = new L.RegularPolygonMarker(
#                 [39.889192, -105.069176],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008169&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008169&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_43892c98d8e6a1b6bc20f9b4079aea9a);
#
#
#         var popup_6ae1a8847133ae23b7af9db1c44c2fb2 = L.popup({&quot;maxWidth&quot;: 300});
#
#
#
#                 var html_9d182aa267ce1ebb2d60ba9fea59e85f = $(`&lt;div id=&quot;html_9d182aa267ce1ebb2d60ba9fea59e85f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User: 0&lt;BR&gt;Coord: &lt;a href=&quot;https://www.google.co.uk/maps/place/39.889192,-105.069176&quot; target=&quot;_blank&quot;&gt;39.8892, -105.0692&lt;/a&gt;&lt;BR&gt;Arr: 2009/07/11 03:30&lt;BR&gt;Dep: 2009/07/11 03:30&lt;/div&gt;`)[0];
#                 popup_6ae1a8847133ae23b7af9db1c44c2fb2.setContent(html_9d182aa267ce1ebb2d60ba9fea59e85f);
#
#
#
#         regular_polygon_marker_14c1ccd0d1ac9e9e994cc31f9544b63a.bindPopup(popup_6ae1a8847133ae23b7af9db1c44c2fb2)
#         ;
#
#
#
#
#             var regular_polygon_marker_8b2879f98e362e295816d3f71aa6bc70 = new L.RegularPolygonMarker(
#                 [39.740384, -104.929457],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#008169&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#008169&quot;, &quot;fillOpacity&quot;: 0.3, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;numberOfSides&quot;: 4, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 12, &quot;rotation&quot;: 0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_43892c98d8e6a1b6bc20f9b4079aea9a);

# %% [markdown]
# ### GPS: the <font color="blue">GeoLife</font> dataset
#
# collected in (Microsoft Research Asia) **[GeoLife](https://www.microsoft.com/en-us/download/details.aspx?id=52367)** project by 182 users in the period Apr 2007 - Aug 2012.
#
# - 17,621 trajectories
# - total distance of about 1.2 million kilometers
# - total duration of 48,000+ hours.
# <center><img src="GeoLife.png" width=800   align="left" /></center>

# %%
tdf = skmob.TrajDataFrame.from_file('data/geolife_sample.txt.gz').sort_values(by='datetime')
print(type(tdf))
print(tdf.crs)
print(tdf.parameters)
tdf.head()
# Out:
# <class 'skmob.core.trajectorydataframe.TrajDataFrame'>
# {'init': 'epsg:4326'}
# {'from_file': 'data/geolife_sample.txt.gz'}
#          lat         lng            datetime  uid
# 0  39.984094  116.319236 2008-10-23 05:53:05    1
# 1  39.984198  116.319322 2008-10-23 05:53:06    1
# 2  39.984224  116.319402 2008-10-23 05:53:11    1
# 3  39.984211  116.319389 2008-10-23 05:53:16    1
# 4  39.984217  116.319422 2008-10-23 05:53:21    1

# %%
tdf.plot_trajectory(zoom=12, weight=3, opacity=0.9, tiles='Stamen Toner')
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a960d305c982e0ed24a2a21d3ef7d8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a960d305c982e0ed24a2a21d3ef7d8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a960d305c982e0ed24a2a21d3ef7d8a = L.map(
#                 &quot;map_9a960d305c982e0ed24a2a21d3ef7d8a&quot;,
#                 {
#                     center: [39.9962335, 116.32167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_9a960d305c982e0ed24a2a21d3ef7d8a);
#
#
#
#
#
#             var tile_layer_7e91a0f0ee701e1acca5c3c940357c00 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9a960d305c982e0ed24a2a21d3ef7d8a);
#
#
#         function geo_json_1e1d012c24a6df0674d021a548f5f5ac_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#00DCB5&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_1e1d012c24a6df0674d021a548f5f5ac_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_1e1d012c24a6df0674d021a548f5f5ac = L.geoJson(null, {
#                 onEachFeature: geo_json_1e1d012c24a6df0674d021a548f5f5ac_onEachFeature,
#
#                 style: geo_json_1e1d012c24a6df0674d021a548f5f5ac_styler,
#         });
#
#         function geo_json_1e1d012c24a6df0674d021a548f5f5ac_add (data) {
#             geo_json_1e1d012c24a6df0674d021a548f5f5ac
#                 .addData(data)
#                 .addTo(map_9a960d305c982e0ed24a2a21d3ef7d8a);
#         }
#             geo_json_1e1d012c24a6df0674d021a548f5f5ac_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [
      %(tdf.iloc[-1].datetime - tdf.iloc[0].datetime))
# Out:
# # users: 2
# # points: 217653
# time window: 146 days 23:53:32

# %% [markdown]
# ## Let's focus on a single user
# using the *select* operation as we do in **pandas**

# %%
user1_tdf = tdf[tdf.uid == 1]
user1_tdf.head(10)
# Out:
#          lat         lng            datetime  uid
# 0  39.984094  116.319236 2008-10-23 05:53:05    1
# 1  39.984198  116.319322 2008-10-23 05:53:06    1
# 2  39.984224  116.319402 2008-10-23 05:53:11    1
# 3  39.984211  116.319389 2008-10-23 05:53:16    1
# 4  39.984217  116.319422 2008-10-23 05:53:21    1
# 5  39.984710  116.319865 2008-10-23 05:53:23    1
# 6  39.984674  116.319810 2008-10-23 05:53:28    1
# 7  39.984623  116.319773 2008-10-23 05:53:33    1
# 8  39.984606  116.319732 2008-10-23 05:53:38    1
# 9  39.984555  116.319728 2008-10-23 05:53:43    1

# %%
user1_map = user1_tdf.plot_trajectory(zoom=11, weight=3, tiles='Open Street Map')
user1_map
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3560625b4fe7544478115c3c5fe6c0e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3560625b4fe7544478115c3c5fe6c0e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3560625b4fe7544478115c3c5fe6c0e2 = L.map(
#                 &quot;map_3560625b4fe7544478115c3c5fe6c0e2&quot;,
#                 {
#                     center: [39.9962335, 116.32167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3560625b4fe7544478115c3c5fe6c0e2);
#
#
#
#
#
#             var tile_layer_81bb813cc44d3f821a46610c7a6e8908 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3560625b4fe7544478115c3c5fe6c0e2);
#
#
#         function geo_json_8888b1403da04fea056a5add35c5d8b6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#00E307&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.75, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_8888b1403da04fea056a5add35c5d8b6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8888b1403da04fea056a5add35c5d8b6 = L.geoJson(null, {
#                 onEachFeature: geo_json_8888b1403da04fea056a5add35c5d8b6_onEachFeature,
#
#                 style: geo_json_8888b1403da04fea056a5add35c5d8b6_styler,
#         });
#
#         function geo_json_8888b1403da04fea056a5add35c5d8b6_add (data) {
#             geo_json_8888b1403da04fea056a5add35c5d8b6
#                 .addData(data)
#                 .addTo(map_3560625b4fe7544478115c3c5fe6c0e2);
#         }
#             geo_json_8888b1403da04fea056a5add35c5d8b6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [
user1_ftdf = filtering.filter(user1_tdf, max_speed_kmh=500.)

# %%
user1_ftdf.parameters
# Out:
# {'from_file': 'data/geolife_sample.txt.gz',
#  'filter': {'function': 'filter',
#   'max_speed_kmh': 500.0,
#   'include_loops': False,
#   'speed_kmh': 5.0,
#   'max_loop': 6,
#   'ratio_max': 0.25}}

# %% [markdown]
# Very few points have been filtered.

# %%
print('Points of the raw trajectory:\t\t%s'%len(user1_tdf))
print('Points of the filtered trajectory:\t%s'%len(user1_ftdf))
print('Filtered points:\t\t\t%s'%(len(user1_tdf)-len(user1_ftdf)))
# Out:
# Points of the raw trajectory:		108607
# Points of the filtered trajectory:	108589
# Filtered points:			18

# %% [markdown]
# ## Compressing trajectories
#
# Reduce the number of points of the trajectory, preserving the structure.

# %% [markdown]
# Merge together all points that are closer than `spatial_radius_km=0.2` kilometers from each other.

# %%
from skmob.preprocessing import compression

# %%
user1_ctdf = compression.compress(user1_ftdf, spatial_radius_km=0.1)
user1_ctdf.head()
# Out:
#          lat         lng            datetime  uid
# 0  39.984578  116.319749 2008-10-23 05:53:05    1
# 1  39.984533  116.320286 2008-10-23 05:54:03    1
# 2  39.984235  116.320923 2008-10-23 05:54:38    1
# 3  39.982974  116.321144 2008-10-23 05:55:54    1
# 4  39.982069  116.321219 2008-10-23 05:56:22    1

# %%
user1_ctdf.parameters
# Out:
# {'from_file': 'data/geolife_sample.txt.gz',
#  'filter': {'function': 'filter',
#   'max_speed_kmh': 500.0,
#   'include_loops': False,
#   'speed_kmh': 5.0,
#   'max_loop': 6,
#   'ratio_max': 0.25},
#  'compress': {'function': 'compress', 'spatial_radius_km': 0.1}}

# %% [markdown]
# The compressed trajectory has only a small fraction of the points of the filtered trajectory.

# %%
print('Points of the filtered trajectory:\t%s'%len(user1_ftdf))
print('Points of the compressed trajectory:\t%s'%len(user1_ctdf))
print('Compressed points:\t\t\t%s'%(len(user1_ftdf)-len(user1_ctdf)))
# Out:
# Points of the filtered trajectory:	108589
# Points of the compressed trajectory:	7099
# Compressed points:			101490

# %% [markdown]
# ## Stop detection
#
# Identify locations where the user spent at least `minutes_for_a_stop` minutes within a distance `spatial_radius_km` $\times$ `stop_radius_factor`, from a given point.
#
# A new column `leaving_datetime` is added, indicating the time when the user departs from the stop.

# %%
from skmob.preprocessing import detection, clustering

# %%
user1_stdf = detection.stay_locations(user1_ctdf, stop_radius_factor=0.5, \
            minutes_for_a_stop=20.0, spatial_radius_km=0.2, 
                       leaving_time=True)
user1_stdf.head()
# Out:
#          lat         lng            datetime  uid    leaving_datetime
# 0  39.978532  116.327267 2008-10-23 06:00:30    1 2008-10-23 10:32:53
# 1  40.013999  116.306183 2008-10-23 11:09:35    1 2008-10-23 23:45:27
# 2  39.979245  116.325659 2008-10-24 00:14:40    1 2008-10-24 01:49:03
# 3  39.981300  116.310084 2008-10-24 01:56:07    1 2008-10-24 03:22:00
# 4  39.979556  116.312931 2008-10-24 03:22:00    1 2008-10-24 03:50:05

# %%
user1_stdf.parameters
# Out:
# {'from_file': 'data/geolife_sample.txt.gz',
#  'filter': {'function': 'filter',
#   'max_speed_kmh': 500.0,
#   'include_loops': False,
#   'speed_kmh': 5.0,
#   'max_loop': 6,
#   'ratio_max': 0.25},
#  'compress': {'function': 'compress', 'spatial_radius_km': 0.1},
#  'detect': {'function': 'stay_locations',
#   'stop_radius_factor': 0.5,
#   'minutes_for_a_stop': 20.0,
#   'spatial_radius_km': 0.2,
#   'leaving_time': True,
#   'no_data_for_minutes': 1000000000000.0,
#   'min_speed_kmh': None}}

# %% [markdown]
# #### Visualise the compressed trajectory and the stops
#
# Click on the stop markers to see a pop up with:
# - User ID
# - Coordinates of the stop (click to see the location on Google maps)
# - Arrival time
# - Departure time

# %%
map_f = user1_stdf.plot_trajectory(max_points=1000, hex_color=-1, start_end_markers=False)
user1_stdf.plot_stops(map_f=map_f, hex_color=-1)
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:646: UserWarning: Only the stops of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_stops(self, map_f=map_f, max_users=max_users, tiles=tiles, zoom=zoom,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b5ce7c2927f9f8039459ff0e2004c9b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b5ce7c2927f9f8039459ff0e2004c9b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b5ce7c2927f9f8039459ff0e2004c9b = L.map(
#                 &quot;map_0b5ce7c2927f9f8039459ff0e2004c9b&quot;,
#                 {
#                     center: [39.980607750000004, 116.32658824999999],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_0b5ce7c2927f9f8039459ff0e2004c9b);
#
#
#
#
#
#             var tile_layer_0b89f22f1b7b664d3644544da520e2e8 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b5ce7c2927f9f8039459ff0e2004c9b);
#
#
#         function geo_json_c95bfa324aae2b45be9ffe5120f0f66b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: -1, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.75, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_c95bfa324aae2b45be9ffe5120f0f66b_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c95bfa324aae2b45be9ffe5120f0f66b = L.geoJson(null, {
#                 onEachFeature: geo_json_c95bfa324aae2b45be9ffe5120f0f66b_onEachFeature,
#
#                 style: geo_json_c95bfa324aae2b45be9ffe5120f0f66b_styler,
#         });
#
#         function geo_json_c95bfa324aae2b45be9ffe5120f0f66b_add (data) {
#             geo_json_c95bfa324aae2b45be9ffe5120f0f66b
#                 .addData(data)
#                 .addTo(map_0b5ce7c2927f9f8039459ff0e2004c9b);
#         }
#             geo_json_c95bfa324aae2b45be9ffe5120f0f66b_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [
# 1  40.013819  116.306532 2008-10-23 11:10:09    1 2008-10-23 23:46:02
# 2  39.978950  116.326439 2008-10-24 00:12:30    1 2008-10-24 01:48:57
# 3  39.981316  116.310181 2008-10-24 01:56:47    1 2008-10-24 02:28:19

# %%
user1_stdf.plot_stops(map_f=user1_map, hex_color=-1)
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:646: UserWarning: Only the stops of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_stops(self, map_f=map_f, max_users=max_users, tiles=tiles, zoom=zoom,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3560625b4fe7544478115c3c5fe6c0e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet-dvf/0.3.0/leaflet-dvf.markers.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3560625b4fe7544478115c3c5fe6c0e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3560625b4fe7544478115c3c5fe6c0e2 = L.map(
#                 &quot;map_3560625b4fe7544478115c3c5fe6c0e2&quot;,
#                 {
#                     center: [39.9962335, 116.32167],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 11,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_3560625b4fe7544478115c3c5fe6c0e2);
#
#
#
#
#
#             var tile_layer_81bb813cc44d3f821a46610c7a6e8908 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3560625b4fe7544478115c3c5fe6c0e2);
#
#
#         function geo_json_8888b1403da04fea056a5add35c5d8b6_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#00E307&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.75, &quot;weight&quot;: 3};
#             }
#         }
#
#         function geo_json_8888b1403da04fea056a5add35c5d8b6_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_8888b1403da04fea056a5add35c5d8b6 = L.geoJson(null, {
#                 onEachFeature: geo_json_8888b1403da04fea056a5add35c5d8b6_onEachFeature,
#
#                 style: geo_json_8888b1403da04fea056a5add35c5d8b6_styler,
#         });
#
#         function geo_json_8888b1403da04fea056a5add35c5d8b6_add (data) {
#             geo_json_8888b1403da04fea056a5add35c5d8b6
#                 .addData(data)
#                 .addTo(map_3560625b4fe7544478115c3c5fe6c0e2);
#         }
#             geo_json_8888b1403da04fea056a5add35c5d8b6_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[116.319236, 39.984094], [116.324395, 39.979764], [116.326728, 39.984062], [116.326543, 39.993742], [116.32167, 40.001626], [116.31591, 40.009559], [116.310135, 40.016448], [116.305591, 40.014572], [116.306529, 40.01382], [116.306526, 40.013859], [116.31256, 40.010884], [116.320113, 40.004924], [116.32627, 39.997362], [116.326817, 39.98674], [116.325772, 39.978983], [116.324616, 39.979582], [116.310814, 39.980075], [116.308814, 39.981103], [116.310729, 39.981595], [116.313583, 39.979542], [116.313722, 39.979553], [116.327028, 39.979859], [116.326168, 39.978777], [116.325387, 39.979729], [116.310938, 39.980088], [116.310485, 39.981422], [116.310913, 39.981931], [116.312635, 39.979568], [116.323849, 39.979524], [116.30576, 40.015904], [116.310613, 40.015327], [116.311899, 40.013635], [116.309028, 40.003765], [116.309026, 39.998026], [116.300121, 39.996491], [116.291189, 39.99598], [116.280083, 39.997194], [116.267794, 40.002691], [116.250253, 40.004855], [116.236305, 39.999345], [116.220385, 39.995421], [116.213343, 39.992248], [116.207124, 39.992479], [116.201177, 39.993741], [116.198934, 39.997028], [116.196825, 39.996838], [116.196669, 39.997212], [116.195698, 39.999913], [116.192199, 40.002138], [116.189877, 40.005311], [116.185017, 40.004414], [116.18101, 40.002771], [116.175774, 40.002766], [116.172672, 40.000699], [116.171119, 40.001718], [116.170751, 40.002577], [116.169433, 40.002429], [116.167575, 40.002232], [116.166736, 40.00174], [116.165926, 40.000155], [116.16209, 39.999291], [116.156125, 39.998647], [116.15132, 39.997193], [116.14741, 39.993966], [116.145321, 39.993154], [116.147363, 39.993923], [116.152825, 39.997664], [116.157881, 39.997812], [116.161717, 39.995573], [116.167572, 39.995071], [116.169461, 39.994648], [116.173318, 39.996042], [116.176718, 39.996848], [116.179708, 39.99684], [116.184516, 39.995428], [116.187584, 39.992407], [116.187005, 39.989942], [116.186206, 39.989155], [116.18821, 39.988959], [116.188529, 39.988176], [116.191276, 39.98977], [116.193994, 39.99103], [116.197219, 39.991895], [116.203145, 39.99146], [116.204994, 39.992475], [116.215251, 39.991429], [116.246945, 40.004265], [116.262046, 40.004073], [116.275639, 40.00045], [116.285521, 39.996866], [116.294892, 39.996003], [116.308795, 39.998014], [116.309348, 40.003968], [116.312223, 40.013299], [116.305672, 40.014134], [116.311501, 40.017163], [116.307487, 40.026715], [116.314128, 40.031998], [116.305672, 40.0437], [116.297114, 40.057642], [116.31043, 40.069592], [116.329794, 40.069405], [116.338666, 40.071323], [116.342078, 40.075335], [116.339464, 40.074122], [116.336552, 40.069872], [116.330634, 40.069676], [116.330137, 40.069522], [116.312949, 40.069538], [116.296869, 40.057774], [116.305267, 40.04412], [116.31408, 40.031764], [116.321623, 40.015654], [116.331197, 40.001672], [116.3315, 39.987848], [116.333701, 39.974835], [116.383644, 39.977135], [116.384162, 3

# %% [markdown]
# ## Stops define <font color="blue">trips</font>
# Let's take the first trip of the individual using the stops

# %%
user1_stdf.head(4)
# Out:
#          lat         lng            datetime  uid    leaving_datetime
# 0  39.978253  116.327275 2008-10-23 06:01:05    1 2008-10-23 10:32:53
# 1  40.013819  116.306532 2008-10-23 11:10:09    1 2008-10-23 23:46:02
# 2  39.978950  116.326439 2008-10-24 00:12:30    1 2008-10-24 01:48:57
# 3  39.981316  116.310181 2008-10-24 01:56:47    1 2008-10-24 02:28:19

# %%
dt1 = user1_stdf.iloc[0].leaving_datetime
dt2 = user1_stdf.iloc[1].leaving_datetime
dt1, dt2
# Out:
# (Timestamp('2008-10-23 10:32:53'), Timestamp('2008-10-23 23:46:02'))

# %%
# select all points between the first two stops
user1_tid1_tdf = user1_tdf[(user1_tdf.datetime >= dt1) 
                           & (user1_tdf.datetime <= dt2)]
user1_tid1_tdf.head()
# Out:
#            lat         lng            datetime  uid
# 148  39.970511  116.341455 2008-10-23 10:32:53    1
# 149  39.977648  116.326925 2008-10-23 10:33:00    1
# 150  39.977586  116.326918 2008-10-23 10:33:05    1
# 151  39.977596  116.326894 2008-10-23 10:33:10    1
# 152  39.977661  116.326947 2008-10-23 10:33:14    1

# %%
# plot the trip
user1_tid1_map = user1_tid1_tdf.plot_trajectory(zoom=13, weight=5, opacity=0.9, tiles='Stamen Toner', )
user1_tid1_map
# Out:
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: Only the trajectories of the first 10 users will be plotted. Use the argument `max_users` to specify the desired number of users, or filter the TrajDataFrame.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# C:\Users\Chokri Hamza\Desktop\sample_project\env\lib\site-packages\skmob\core\trajectorydataframe.py:569: UserWarning: If necessary, trajectories will be down-sampled to have at most `max_points` points. To avoid this, specify `max_points=None`.
#   return plot.plot_trajectory(self, map_f=map_f, max_users=max_users, max_points=max_points, style_function=style_function,
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c1a36f5d59ff625f41b2ac3260804db5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c1a36f5d59ff625f41b2ac3260804db5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c1a36f5d59ff625f41b2ac3260804db5 = L.map(
#                 &quot;map_c1a36f5d59ff625f41b2ac3260804db5&quot;,
#                 {
#                     center: [40.011313, 116.312443],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_c1a36f5d59ff625f41b2ac3260804db5);
#
#
#
#
#
#             var tile_layer_2e7a4d14287510534a7609b41b7147c4 = L.tileLayer(
#                 &quot;https://stamen-tiles-{s}.a.ssl.fastly.net/toner/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Map tiles by \u003ca href=\&quot;http://stamen.com\&quot;\u003eStamen Design\u003c/a\u003e, under \u003ca href=\&quot;http://creativecommons.org/licenses/by/3.0\&quot;\u003eCC BY 3.0\u003c/a\u003e. Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c1a36f5d59ff625f41b2ac3260804db5);
#
#
#         function geo_json_b47d5e41aad5113f62de89d4b3b1ca94_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#FF71FD&quot;, &quot;dashArray&quot;: &quot;0, 0&quot;, &quot;opacity&quot;: 0.9, &quot;weight&quot;: 5};
#             }
#         }
#
#         function geo_json_b47d5e41aad5113f62de89d4b3b1ca94_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_b47d5e41aad5113f62de89d4b3b1ca94 = L.geoJson(null, {
#                 onEachFeature: geo_json_b47d5e41aad5113f62de89d4b3b1ca94_onEachFeature,
#
#                 style: geo_json_b47d5e41aad5113f62de89d4b3b1ca94_styler,
#         });
#
#         function geo_json_b47d5e41aad5113f62de89d4b3b1ca94_add (data) {
#             geo_json_b47d5e41aad5113f62de89d4b3b1ca94
#                 .addData(data)
#                 .addTo(map_c1a36f5d59ff625f41b2ac3260804db5);
#         }
#             geo_json_b47d5e41aad5113f62de89d4b3b1ca94_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[116.341455, 39.970511], [116.326925, 39.977648], [116.326918, 39.977586], [116.326894, 39.977596], [116.326947, 39.977661], [116.326951, 39.977647], [116.326857, 39.977653], [116.326887, 39.977688], [116.326978, 39.977748], [116.326995, 39.97781], [116.327128, 39.977909], [116.327218, 39.977979], [116.327214, 39.978093], [116.32719, 39.978198], [116.327165, 39.978254], [116.327255, 39.978273], [116.327279, 39.978385], [116.327293, 39.978487], [116.327292, 39.978611], [116.327293, 39.97872], [116.327292, 39.978803], [116.327259, 39.978883], [116.327242, 39.978971], [116.327244, 39.979016], [116.327211, 39.979017], [116.327154, 39.979013], [116.327131, 39.979088], [116.327143, 39.979104], [116.327168, 39.979195], [116.327209, 39.979293], [116.327208, 39.979394], [116.327198, 39.979497], [116.327197, 39.979629], [116.327182, 39.979719], [116.327185, 39.979831], [116.327151, 39.979919], [116.327109, 39.979973], [116.327084, 39.980092], [116.327037, 39.980126], [116.326994, 39.980188], [116.326988, 39.98028], [116.326978, 39.980404], [116.326976, 39.980522], [116.326933, 39.980658], [116.326905, 39.980765], [116.326873, 39.98087], [116.32682, 39.980956], [116.326798, 39.981364], [116.326765, 39.981473], [116.326759, 39.981748], [116.326767, 39.981959], [116.326757, 39.982049], [116.326752, 39.982175], [116.326754, 39.98228], [116.326752, 39.982387], [116.326766, 39.982508], [116.32673, 39.982601], [116.326684, 39.982675], [116.32671, 39.982808], [116.326697, 39.982922], [116.326693, 39.983115], [116.326708, 39.983215], [116.326707, 39.98336], [116.326665, 39.983434], [116.326665, 39.983559], [116.326661, 39.983719], [116.326694, 39.983839], [116.326715, 39.983933], [116.326728, 39.984062], [116.326753, 39.984142], [116.326724, 39.984164], [116.326723, 39.984262], [116.326715, 39.984354], [116.326711, 39.984457], [116.326696, 39.984559], [116.326711, 39.984669], [116.326683, 39.984783], [116.326672, 39.984889], [116.326677, 39.985019], [116.326694, 39.985106], [116.326686, 39.985197], [116.326664, 39.985304], [116.32661, 39.985454], [116.326565, 39.985546], [116.326589, 39.985645], [116.326618, 39.985752], [116.326633, 39.98585], [116.326605, 39.985948], [116.326554, 39.986049], [116.326524, 39.986141], [116.326502, 39.986234], [116.326464, 39.98631], [116.326442, 39.986409], [116.326476, 39.986534], [116.326505, 39.986654], [116.326486, 39.986744], [116.3265, 39.98685], [116.326512, 39.986948], [116.326512, 39.987047], [116.326512, 39.987142], [116.326502, 39.987248], [116.326511, 39.987344], [116.326519, 39.987398], [116.326508, 39.987456], [116.326498, 39.987562], [116.3265, 39.987671], [116.326508, 39.987888], [116.326502, 39.98803], [116.326492, 39.98813], [116.326499, 39.988222], [116.326498, 39.988316], [116.326486, 39.988416], [116.326463, 39.988512], [116.326457, 39.988603], [116.32

# %% [markdown]
# Compute the length of the trip and the distance between origin and destination

# %%
from skmob.utils.gislib import getDistanceByHaversine
from skmob.measures.individual import distance_straight_line
# take origin and destination of the trip
start_loc = user1_tid1_tdf.iloc[0][['lat', 'lng']]
end_loc = user1_tid1_tdf.iloc[-1][['lat', 'lng']]
# compute distance between origin and destination
print("distance:", getDistanceByHaversine(end_loc, start_loc))
# Out:
# distance: 5.511092656068364

# %%
distance_straight_line(user1_tid1_tdf)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 110.81it/s]
#    uid  distance_straight_line
# 0    1                8.713016

# %% [markdown]
# ## Compute some features based on trips

# %%
def number_of_trips(tdf, stop_radius_factor=0.5, minutes_for_a_stop=20.0, spatial_radius_km=0.2):
    """
    Compute the number of trips for each object.
    """
    # detect the stops for each individual
    stdf = detection.stay_locations(tdf, stop_radius_factor=stop_radius_factor, 
                             minutes_for_a_stop=minutes_for_a_stop, 
                           spatial_radius_km=spatial_radius_km, leaving_time=True)
    return stdf.groupby('uid').apply(lambda user_stdf: len(user_stdf)).reset_index().rename(columns={0: 'n_trips'})

# %%
number_of_trips(tdf)
# Out:
#    uid  n_trips
# 0    1      161
# 1    5      252

# %%
def number_of_evening_trips(tdf, stop_radius_factor=0.5, minutes_for_a_stop=20.0, 
                                   spatial_radius_km=0.2):
    """
    Number of subtrajectories that end in the evening.
    """
    def get_evening_trips(user_stdf, evening_time=['16:00', '20:00']):
        start_evening, end_evening = evening_time
        return len(user_stdf.set_index('leaving_datetime').between_time(start_evening, 
                                                                end_evening))
    stdf = detection.stay_locations(tdf, stop_radius_factor=stop_radius_factor, 
                             minutes_for_a_stop=minutes_for_a_stop, 
                           spatial_radius_km=spatial_radius_km, 
                             leaving_time=True)
    return stdf.groupby('uid').apply(lambda user_stdf: get_evening_trips(user_stdf)).reset_index().rename(columns={0: 'evening_trips'})

# %%
number_of_evening_trips(tdf)
# Out:
#    uid  evening_trips
# 0    1              2
# 1    5             24

# %%
def average_stops_per_day(tdf, stop_radius_factor=0.5, minutes_for_a_stop=20.0, 
                                   spatial_radius_km=0.2):
    """
    Average number of stops per day
    """
    def get_stops_per_day(user_stdf):
        return user_stdf.groupby(user_stdf.leaving_datetime.dt.floor('d')).size().reset_index(name='count').mean()

    stdf = detection.stay_locations(tdf, stop_radius_factor=stop_radius_factor, 
                             minutes_for_a_stop=minutes_for_a_stop, 
                           spatial_radius_km=spatial_radius_km, 
                             leaving_time=True)
    return stdf.groupby('uid').apply(lambda user_stdf: get_stops_per_day(user_stdf)).reset_index().rename(columns={'count': 'avg_stops_per_day'})

# %%
tdf
# Out:
#               lat         lng            datetime  uid
# 0       39.984094  116.319236 2008-10-23 05:53:05    1
# 1       39.984198  116.319322 2008-10-23 05:53:06    1
# 2       39.984224  116.319402 2008-10-23 05:53:11    1
# 3       39.984211  116.319389 2008-10-23 05:53:16    1
# 4       39.984217  116.319422 2008-10-23 05:53:21    1
# ...           ...         ...                 ...  ...
# 217648  39.999896  116.327290 2009-03-19 05:46:02    5
# 217649  39.999899  116.327352 2009-03-19 05:46:07    5
# 217650  39.999945  116.327394 2009-03-19 05:46:12    5
# 217651  40.000015  116.327433 2009-03-19 05:46:17    5
# 217652  39.999978  116.327460 2009-03-19 05:46:37    5
#
# [217653 rows x 4 columns]

# %%
average_stops_per_day(tdf)
# Out:
# C:\Users\Chokri Hamza\AppData\Local\Temp\ipykernel_29692\4255827731.py:7: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   return user_stdf.groupby(user_stdf.leaving_datetime.dt.floor('d')).size().reset_index(name='count').mean()
# C:\Users\Chokri Hamza\AppData\Local\Temp\ipykernel_29692\4255827731.py:7: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   return user_stdf.groupby(user_stdf.leaving_datetime.dt.floor('d')).size().reset_index(name='count').mean()
# C:\Users\Chokri Hamza\AppData\Local\Temp\ipykernel_29692\4255827731.py:7: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   return user_stdf.groupby(user_stdf.leaving_datetime.dt.floor('d')).size().reset_index(name='count').mean()
# C:\Users\Chokri Hamza\AppData\Local\Temp\ipykernel_29692\4255827731.py:7: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   return user_stdf.groupby(user_stdf.leaving_datetime.dt.floor('d')).size().reset_index(name='count').mean()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\groupby.py:1423, in GroupBy.apply(self, func, *args, **kwargs)
#    1422 try:
# -> 1423     result = self._python_apply_general(f, self._selected_obj)
#    1424 except TypeError:
#    1425     # gh-20949
#    1426     # try again, with .apply acting as a filtering
#    (...)
#    1430     # fails on *some* columns, e.g. a numeric operation
#    1431     # on a string grouper column
#
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\groupby.py:1469, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1467     not_indexed_same = mutated or self.mutated
# -> 1469 return self._wrap_applied_output(
#    1470     data, values, not_indexed_same=not_indexed_same
#    1471 )
#
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\generic.py:1032, in DataFrameGroupBy._wrap_applied_output(self, data, values, not_indexed_same)
#    1030 else:
#    1031     # values are Series
# -> 1032     return self._wrap_applied_output_series(
#    1033         values, not_indexed_same, first_not_none, key_index
#    1034     )
#
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\generic.py:1098, in DataFrameGroupBy._wrap_applied_output_series(self, values, not_indexed_same, first_not_none, key_index)
#    1097     stacked_values = stacked_values.tolist()
# -> 1098 result = self.obj._constructor(stacked_values, index=index, columns=columns)
#    1100 if not self.as_index:
#
# TypeError: TrajDataFrame.__init__() got an unexpected keyword argument 'index'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [89], in <cell line: 1>()
# ----> 1 average_stops_per_day(tdf)
#
# Input In [86], in average_stops_per_day(tdf, stop_radius_factor, minutes_for_a_stop, spatial_radius_km)
#       7     return user_stdf.groupby(user_stdf.leaving_datetime.dt.floor('d')).size().reset_index(name='count').mean()
#       9 stdf = detection.stay_locations(tdf, stop_radius_factor=stop_radius_factor,
#      10                          minutes_for_a_stop=minutes_for_a_stop,
#      11                        spatial_radius_km=spatial_radius_km,
#      12                          leaving_time=True)
# ---> 13 return stdf.groupby('uid').apply(lambda user_stdf: get_stops_per_day(user_stdf)).rename(columns={'count': 'avg_stops_per_day'})
#
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\groupby.py:1434, in GroupBy.apply(self, func, *args, **kwargs)
#    1424     except TypeError:
#    1425         # gh-20949
#    1426         # try again, with .apply acting as a filtering
#    (...)
#    1430         # fails on *some* columns, e.g. a numeric operation
#    1431         # on a string grouper column
#    1433         with self._group_selection_context():
# -> 1434             return self._python_apply_general(f, self._selected_obj)
#    1436 return result
#
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\groupby.py:1469, in GroupBy._python_apply_general(self, f, data, not_indexed_same)
#    1466 if not_indexed_same is None:
#    1467     not_indexed_same = mutated or self.mutated
# -> 1469 return self._wrap_applied_output(
#    1470     data, values, not_indexed_same=not_indexed_same
#    1471 )
#
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\generic.py:1032, in DataFrameGroupBy._wrap_applied_output(self, data, values, not_indexed_same)
#    1029         return result
#    1030 else:
#    1031     # values are Series
# -> 1032     return self._wrap_applied_output_series(
#    1033         values, not_indexed_same, first_not_none, key_index
#    1034     )
#
# File ~\Desktop\sample_project\env\lib\site-packages\pandas\core\groupby\generic.py:1098, in DataFrameGroupBy._wrap_applied_output_series(self, values, not_indexed_same, first_not_none, key_index)
#    1095 if stacked_values.dtype == object:
#    1096     # We'll have the DataFrame constructor do inference
#    1097     stacked_values = stacked_values.tolist()
# -> 1098 result = self.obj._constructor(stacked_values, index=index, columns=columns)
#    1100 if not self.as_index:
#    1101     self._insert_inaxis_grouper_inplace(result)
#
# TypeError: TrajDataFrame.__init__() got an unexpected keyword argument 'index'
